# %% [markdown]
# # Agustin Balce Assignment 3 (Utilizing RNN and LSTM for Stock Prediction)

# %% [markdown]
# ## Check Python Version

# %%
import sys
sys.version_info #Python version 3.9.12
# Out:
# sys.version_info(major=3, minor=10, micro=12, releaselevel='final', serial=0)

# %% [markdown]
# ## Import Setup

# %%
import pandas as pd  # for data visualization
import numpy as np
import matplotlib.pyplot as plt  # for plotting graphs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout  # layers for the neural network
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error  # for calculating MSE
#from kerastuner import HyperParameters  # for tuning hyperparameters
#import tensorflow.keras as keras
#import keras.layers as layers  # Different layers for neural networks
#from kerastuner.tuners import RandomSearch  # Random search for hyperparameter tuning
import seaborn as sns  # for better visualization

# Setting seaborn and matplotlib for plotting
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

# Enable inline plotting for matplotlib
# %matplotlib inline

# %% [markdown]
# ## Spliting and Displaying the Data

# %%
dataframe_test = pd.read_csv('./Google_Stock_Price_Test.csv')
dataframe_train = pd.read_csv('./Google_Stock_Price_Train.csv')
df = pd.concat([dataframe_train,dataframe_test])

# %%
df.head() # extracted data for year 2012
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
df.tail() # extracted data for year 2017
# Out:
#          Date    Open    High     Low   Close     Volume
# 15  1/25/2017  829.62  835.77  825.06  835.67  1,494,500
# 16  1/26/2017  837.81  838.00  827.01  832.15  2,973,900
# 17  1/27/2017  834.71  841.95  820.44  823.31  2,965,800
# 18  1/30/2017  814.66  815.84  799.80  802.32  3,246,600
# 19  1/31/2017  796.86  801.25  790.52  796.79  2,160,600

# %% [markdown]
# ## Preprocessing of Data

# %%
df.info() # to check the summary of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1278 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1278 non-null   object
#  1   Open    1278 non-null   float64
#  2   High    1278 non-null   float64
#  3   Low     1278 non-null   float64
#  4   Close   1278 non-null   object
#  5   Volume  1278 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 69.9+ KB

# %%
df.describe() # view statistics
# Out:
#               Open         High          Low
# count  1278.000000  1278.000000  1278.000000
# mean    537.994906   542.168897   533.278803
# std     154.508365   155.582501   153.174011
# min     279.120000   281.210000   277.220000
# 25%     406.037500   408.230000   403.335000
# 50%     538.395000   542.330000   534.355000
# 75%     668.862500   677.705000   662.190000
# max     837.810000   841.950000   827.010000

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.shape
# Out:
# (1278, 6)

# %%
df.isnull().sum() #to check for missing and null values
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close      object
# Volume     object
# dtype: object

# %%
sns.heatmap(data=dataframe_train.corr(), annot=True, cmap='summer') # Creating a heatmap with the correlation matrix of the 'df_train' DataFrame
# Out:
# <ipython-input-14-a48c34a5f22b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=dataframe_train.corr(), annot=True, cmap='summer') # Creating a heatmap with the correlation matrix of the 'df_train' DataFrame
# <Axes: >

# %%
df = df.loc[:,["Open"]].values
train = df[:len(df)-50]
test = df[len(train):]
# reshape
train = train.reshape(train.shape[0],1)

# %%
train.shape
# Out:
# (1228, 1)

# %%
plt.plot(train);
plt.title("Opening prices for the data");
plt.xlabel("Days ")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# ## Normalization / Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0,1)) # defining of Scaler
train_scaled = scaler.fit_transform(train) # applying to Scaler to train
plt.plot(train_scaled)
plt.xlabel("Days ")
plt.ylabel("Open Price")
plt.title("Stock price after scaling")
plt.show()

# %% [markdown]
# ## Generating X_train and y_train Sets from Scaled Training Data

# %%
# We add first 50 timesteps to "X_train" and  51 timesteps to "y_train" .
X_train = []
y_train = []
timesteps = 50

for i in range(timesteps, train_scaled.shape[0]):
    X_train.append(train_scaled[i-timesteps:i,0])
    y_train.append(train_scaled[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)


# Reshaping
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %% [markdown]
# ## Creation of the RNN Model (Training, Validation)

# %%
# --- RNN Construction ---

# Import required modules from Keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout

# Create a Sequential model
model = Sequential()

# Add the initial RNN layer with Dropout for regularization
model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))

# Include additional RNN layers with Dropout for regularization
for _ in range(2):
    model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True))
    model.add(Dropout(0.2))

# Add the final RNN layer without return_sequences
model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

# Append the output layer to the model
model.add(Dense(units=1))

# Compile the model with the adam optimizer and mean squared error as the loss function
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model on the training data with validation
training_history = model.fit(X_train, y_train, epochs=100, batch_size=32,validation_split=0.1)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 5s 55ms/step - loss: 0.3575 - val_loss: 0.0030
# Epoch 2/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.2853 - val_loss: 0.0467
# Epoch 3/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.1723 - val_loss: 0.0115
# Epoch 4/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.1570 - val_loss: 0.0305
# Epoch 5/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.1260 - val_loss: 0.0150
# Epoch 6/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0882 - val_loss: 7.3586e-04
# Epoch 7/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0784 - val_loss: 0.0040
# Epoch 8/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0707 - val_loss: 0.0034
# Epoch 9/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0622 - val_loss: 0.0046
# Epoch 10/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0530 - val_loss: 0.0013
# Epoch 11/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0451 - val_loss: 0.0055
# Epoch 12/100
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0408 - val_loss: 0.0014
# Epoch 13/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0383 - val_loss: 0.0014
# Epoch 14/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0368 - val_loss: 0.0029
# Epoch 15/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0321 - val_loss: 0.0014
# Epoch 16/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0293 - val_loss: 0.0032
# Epoch 17/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0257 - val_loss: 9.7933e-04
# Epoch 18/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0249 - val_loss: 0.0030
# Epoch 19/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0250 - val_loss: 0.0034
# Epoch 20/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0214 - val_loss: 0.0047
# Epoch 21/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0187 - val_loss: 0.0041
# Epoch 22/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0175 - val_loss: 0.0016
# Epoch 23/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0172 - val_loss: 0.0029
# Epoch 24/100
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0161 - val_loss: 0.0012
# Epoch 25/100
# 34/34 [==============================] - 1s 44ms/step - loss: 0.0140 - val_loss: 0.0032
# Epoch 26/100
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0140 - val_loss: 6.9472e-04
# Epoch 27/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0117 - val_loss: 8.8023e-04
# Epoch 28/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0124 - val_loss: 0.0015
# Epoch 29/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0110 - val_loss: 9.1819e-04
# Epoch 30/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0104 - val_loss: 0.0027
# Epoch 31/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0101 - val_loss: 0.0011
# Epoch 32/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0096 - val_loss: 6.1293e-04
# Epoch 33/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0081 - val_loss: 6.5722e-04
# Epoch 34/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0083 - val_loss: 7.4835e-04
# Epoch 35/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0084 - val_loss: 6.8175e-04
# Epoch 36/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0075 - val_loss: 7.0857e-04
# Epoch 37/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0079 - val_loss: 8.0436e-04
# Epoch 38/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0078 - val_loss: 6.1494e-04
# Epoch 39/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0079 - val_loss: 0.0015
# Epoch 40/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0068 - val_loss: 7.2235e-04
# Epoch 41/100
# 34/34 [==============================] - 1s 37ms/step - loss: 0.0069 - val_loss: 6.4054e-04
# Epoch 42/100
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0072 - val_loss: 0.0012
# Epoch 43/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 44/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0061 - val_loss: 0.0019
# Epoch 45/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0057 - val_loss: 6.4403e-04
# Epoch 46/100
# 34/34 [==============================] - 1s 36ms/step - loss: 0.0054 - val_loss: 6.8007e-04
# Epoch 47/100
# 34/34 [==============================] - 1s 44ms/step - loss: 0.0056 - val_loss: 6.9949e-04
# Epoch 48/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 49/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0060 - val_loss: 6.0356e-04
# Epoch 50/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0051 - val_loss: 5.6840e-04
# Epoch 51/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 52/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0045 - val_loss: 8.4832e-04
# Epoch 53/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 54/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0044 - val_loss: 6.5306e-04
# Epoch 55/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 56/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0044 - val_loss: 5.4492e-04
# Epoch 57/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0044 - val_loss: 6.5244e-04
# Epoch 58/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0041 - val_loss: 7.3622e-04
# Epoch 59/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 60/100
# 34/34 [==============================] - 1s 36ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 61/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0039 - val_loss: 7.0504e-04
# Epoch 62/100
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 63/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0041 - val_loss: 6.5232e-04
# Epoch 64/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0034 - val_loss: 7.5888e-04
# Epoch 65/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 66/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 8.2631e-04
# Epoch 67/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 68/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 69/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 70/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0033 - val_loss: 7.7744e-04
# Epoch 71/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0033 - val_loss: 7.8812e-04
# Epoch 72/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 73/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 74/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0031 - val_loss: 7.8702e-04
# Epoch 75/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 9.1529e-04
# Epoch 76/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 77/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 9.1557e-04
# Epoch 78/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 79/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 80/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0025 - val_loss: 8.1143e-04
# Epoch 81/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 82/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 83/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0025 - val_loss: 8.5721e-04
# Epoch 84/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 85/100
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 86/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 87/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 88/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 89/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 90/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 91/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 92/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 93/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 94/100
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 95/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 96/100
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 97/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 98/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 99/100
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 100/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0024 - val_loss: 0.0015

# %% [markdown]
# ## Assessing the Performance of the Model

# %%
# Losses
training_history.history["loss"]
# Out:
# [0.3574675917625427,
#  0.28527092933654785,
#  0.1723470538854599,
#  0.1570044457912445,
#  0.12600082159042358,
#  0.08820948749780655,
#  0.07844626903533936,
#  0.07065271586179733,
#  0.062187373638153076,
#  0.052979230880737305,
#  0.045121196657419205,
#  0.040770046412944794,
#  0.03826045244932175,
#  0.036846403032541275,
#  0.03209129720926285,
#  0.02931189350783825,
#  0.025702808052301407,
#  0.024856191128492355,
#  0.02500608004629612,
#  0.021412111818790436,
#  0.01866011880338192,
#  0.017461832612752914,
#  0.0172433964908123,
#  0.0161459781229496,
#  0.01395674329251051,
#  0.013967280276119709,
#  0.011709770187735558,
#  0.012428044341504574,
#  0.010978259146213531,
#  0.01044166088104248,
#  0.010076014325022697,
#  0.009597434662282467,
#  0.008095654658973217,
#  0.008303946815431118,
#  0.008400991559028625,
#  0.007455888669937849,
#  0.007856938056647778,
#  0.007838373072445393,
#  0.007886042818427086,
#  0.006842445116490126,
#  0.006902375724166632,
#  0.007244796026498079,
#  0.006232587154954672,
#  0.006079916376620531,
#  0.005726951640099287,
#  0.005376034416258335,
#  0.005563199520111084,
#  0.006545088719576597,
#  0.005969263147562742,
#  0.00513579323887825,
#  0.00492342934012413,
#  0.004542867187410593,
#  0.004901640582829714,
#  0.004354594275355339,
#  0.005129444412887096,
#  0.004403063096106052,
#  0.0044099497608840466,
#  0.0040517100133001804,
#  0.004266675096005201,
#  0.003899905364960432,
#  0.003946593031287193,
#  0.004048552829772234,
#  0.0040829177014529705,
#  0.003427352989092469,
#  0.0035692821256816387,
#  0.0034533285070210695,
#  0.003761210246011615,
#  0.0035756276920437813,
#  0.003565429011359811,
#  0.0032729115337133408,
#  0.003285658545792103,
#  0.0031581276562064886,
#  0.003307536942884326,
#  0.0031173834577202797,
#  0.003026580670848489,
#  0.003070060396566987,
#  0.0030211748089641333,
#  0.0029169898480176926,
#  0.00258793868124485,
#  0.0025483067147433758,
#  0.002849990501999855,
#  0.0025650784373283386,
#  0.0025138079654425383,
#  0.002582812448963523,
#  0.0022729565389454365,
#  0.002741583390161395,
#  0.0029594574589282274,
#  0.0025510969571769238,
#  0.0023529205936938524,
#  0.0023653849493712187,
#  0.002892696764320135,
#  0.002612943993881345,
#  0.0025025098584592342,
#  0.002349145244807005,
#  0.002239067805930972,
#  0.0024240196216851473,
#  0.0024997820146381855,
#  0.0023874028120189905,
#  0.0022000407334417105,
#  0.002428951673209667]

# %%
min_loss = np.min(training_history.history["loss"])
RMSE = math.sqrt(min_loss)
RMSE
# Out:
# 0.046904591816172014

# %%
# Visualizing Loss over Epochs
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.title('Simple RNN Model, Loss vs Epoch')
plt.legend()
plt.show()

# %%
data_inputs = df[-(len(test) + timesteps):]
scaled_inputs = scaler.transform(data_inputs)  # Apply min-max scaling

# %%
X_test = []
for i in range(timesteps, data_inputs.shape[0]):
    X_test.append(data_inputs[i-timesteps:i, 0]) # We get 50 elements by shifting from 0 to 50 and from 1 to 51.
X_test = np.array(X_test)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ## Model predictions for train data

# %%
predicted_data = model.predict(X_test)
predicted_data = scaler.inverse_transform(predicted_data)
# Out:
# 2/2 [==============================] - 0s 10ms/step

# %%
rmse = np.sqrt(np.mean(((predicted_data - test) ** 2)))
rmse
# Out:
# 10.575693806134018

# %%
plt.figure(figsize=(8,4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(test,color="orange",label="Real value")
plt.plot(predicted_data,color="c",label="RNN predicted result")
plt.legend()
plt.xlabel("Days")
plt.ylabel("Values")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Creating LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
model = Sequential()
model.add(LSTM(10, input_shape=(None,1)))
model.add(Dense(1))
model.compile(loss="mean_squared_error",optimizer='Adam')
history=model.fit(X_train,y_train,epochs=50, batch_size=1)
# Out:
# Epoch 1/50
# 1178/1178 [==============================] - 10s 7ms/step - loss: 0.0100
# Epoch 2/50
# 1178/1178 [==============================] - 9s 8ms/step - loss: 0.0010
# Epoch 3/50
# 1178/1178 [==============================] - 9s 7ms/step - loss: 8.0498e-04
# Epoch 4/50
# 1178/1178 [==============================] - 9s 7ms/step - loss: 7.2886e-04
# Epoch 5/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 6.0736e-04
# Epoch 6/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 5.3590e-04
# Epoch 7/50
# 1178/1178 [==============================] - 9s 8ms/step - loss: 4.8364e-04
# Epoch 8/50
# 1178/1178 [==============================] - 9s 8ms/step - loss: 4.3097e-04
# Epoch 9/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 4.1820e-04
# Epoch 10/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.9571e-04
# Epoch 11/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.8613e-04
# Epoch 12/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.4859e-04
# Epoch 13/50
# 1178/1178 [==============================] - 9s 7ms/step - loss: 3.4331e-04
# Epoch 14/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 3.2919e-04
# Epoch 15/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.2550e-04
# Epoch 16/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.1995e-04
# Epoch 17/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.2030e-04
# Epoch 18/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.1123e-04
# Epoch 19/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.0759e-04
# Epoch 20/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 3.1287e-04
# Epoch 21/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.0872e-04
# Epoch 22/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.1901e-04
# Epoch 23/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 2.9289e-04
# Epoch 24/50
# 1178/1178 [==============================] - 8s 6ms/step - loss: 2.9942e-04
# Epoch 25/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9892e-04
# Epoch 26/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.0004e-04
# Epoch 27/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.0098e-04
# Epoch 28/50
# 1178/1178 [==============================] - 9s 7ms/step - loss: 2.9615e-04
# Epoch 29/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.0473e-04
# Epoch 30/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.0022e-04
# Epoch 31/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9761e-04
# Epoch 32/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 2.8965e-04
# Epoch 33/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 2.9615e-04
# Epoch 34/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 3.1291e-04
# Epoch 35/50
# 1178/1178 [==============================] - 8s 6ms/step - loss: 2.9292e-04
# Epoch 36/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9384e-04
# Epoch 37/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9275e-04
# Epoch 38/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9394e-04
# Epoch 39/50
# 1178/1178 [==============================] - 8s 6ms/step - loss: 2.7980e-04
# Epoch 40/50
# 1178/1178 [==============================] - 8s 6ms/step - loss: 3.0119e-04
# Epoch 41/50
# 1178/1178 [==============================] - 8s 6ms/step - loss: 2.9567e-04
# Epoch 42/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9977e-04
# Epoch 43/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 3.0744e-04
# Epoch 44/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9407e-04
# Epoch 45/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9339e-04
# Epoch 46/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9738e-04
# Epoch 47/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9126e-04
# Epoch 48/50
# 1178/1178 [==============================] - 7s 6ms/step - loss: 2.9409e-04
# Epoch 49/50
# 1178/1178 [==============================] - 8s 7ms/step - loss: 2.8365e-04
# Epoch 50/50
# 1178/1178 [==============================] - 8s 6ms/step - loss: 2.9750e-04

# %%
plt.figure(figsize =(10,5))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Loss vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions

# %%
predicted_data2=model.predict(X_test)
predicted_data2=scaler.inverse_transform(predicted_data2)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
min_loss = np.min(history.history['loss'])
RMSE = math.sqrt(min_loss)
RMSE
# Out:
# 0.016727353120752835

# %%
rmse = np.sqrt(np.mean(((predicted_data2 - test) ** 2)))
rmse
# Out:
# 8.278525357186913

# %%
plt.figure(figsize=(8,4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(test,color="LimeGreen",label="Real values")
plt.plot(predicted_data2,color="Gold",label="Predicted LSTM result")
plt.legend()
plt.xlabel("Days")
plt.ylabel("Values")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Comparative Analysis of Predictions from RNN and LSTM Models

# %%
import matplotlib.pyplot as plt

# Set up the plot dimensions, background, and edge colors
plt.figure(figsize=(8,4), dpi=80, background='white', edge_color='black')

# Plot the actual values and predicted results
plt.plot(test, color="green", linestyle='--', label="Real Values")
plt.plot(predicted_data2, color="blue", label="LSTM predicted result")
plt.plot(predicted_data, color="red", label="RNN predicted result")

# Add legend, labels, and grid
plt.legend(loc='best')
plt.xlabel("Days)")
plt.ylabel("Real values")
plt.grid(visible=True)

# Display the plot
plt.show()
